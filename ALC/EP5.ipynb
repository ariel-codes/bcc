# %% [markdown]
# # Exercício de Programação 5: Regressão
#
# <font color="red">**Prazo de submissão: 23:55 do dia 16/03/2021** </font>
#
# 2020.2 Álgebra Linear Computacional - DCC - UFMG
#
# Erickson - Fabricio
#
# Instruções:
# * Antes de submeter suas soluções, certifique-se de que tudo roda como esperado. Primeiro, **reinicie o kernel** no menu, selecione Kernel$\rightarrow$Restart e então execute **todas as células** (no menu, Cell$\rightarrow$Run All)
# * Apenas o arquivo .ipynb deve ser submetido. Ele não deve ser compactado.
# * Não deixe de preencher seu nome e número de matrícula na célula a seguir
#
# **Nome do aluno:** Ariel Augusto dos Santos
#
# **Matricula:** 2017068726

# %% [markdown]
# ## Carregando os dados
#
# Iremos carregar os dados usando a biblioteca ```pandas```. Não se preocupe se você não conhece a biblioteca, pois o nosso objetivo é apenas extrair a matriz de dados $X$. Segue uma descrição do dataset, retirada [daqui](http://statweb.stanford.edu/~owen/courses/202/Cereals.txt).
#
# * Datafile Name: Cereals
# * Datafile Subjects: Food , Health
# * Story Names: Healthy Breakfast
# * Reference: Data available at many grocery stores
# * Authorization: free use
# * Description: Data on several variable of different brands of cereal.
#
# A value of -1 for nutrients indicates a missing observation.
# Number of cases: 77
# Variable Names:
#
#   1. Name: Name of cereal
#   2. mfr: Manufacturer of cereal where A = American Home Food Products; G =
#      General Mills; K = Kelloggs; N = Nabisco; P = Post; Q = Quaker Oats; R
#      = Ralston Purina
#   3. type: cold or hot
#   4. calories: calories per serving
#   5. protein: grams of protein
#   6. fat: grams of fat
#   7. sodium: milligrams of sodium
#   8. fiber: grams of dietary fiber
#   9. carbo: grams of complex carbohydrates
#   10. sugars: grams of sugars
#   11. potass: milligrams of potassium
#   12. vitamins: vitamins and minerals - 0, 25, or 100, indicating the typical percentage of FDA recommended
#   13. shelf: display shelf (1, 2, or 3, counting from the floor)
#   14. weight: weight in ounces of one serving
#   15. cups: number of cups in one serving
#   16. rating: a rating of the cereals

# %%
#Execute esta célula para instalar o pandas caso já não tenha instalado
# import sys
# !{sys.executable} -m pip install --user pandas

# %%
import pandas as pd
df = pd.read_table('cereal.txt',sep='\s+',index_col='name')
df
# Out:
#                                        mfr type  calories  protein  fat  \
# name
# 100%_Bran                                N    C        70        4    1
# 100%_Natural_Bran                        Q    C       120        3    5
# All-Bran                                 K    C        70        4    1
# All-Bran_with_Extra_Fiber                K    C        50        4    0
# Almond_Delight                           R    C       110        2    2
# Apple_Cinnamon_Cheerios                  G    C       110        2    2
# Apple_Jacks                              K    C       110        2    0
# Basic_4                                  G    C       130        3    2
# Bran_Chex                                R    C        90        2    1
# Bran_Flakes                              P    C        90        3    0
# Cap'n'Crunch                             Q    C       120        1    2
# Cheerios                                 G    C       110        6    2
# Cinnamon_Toast_Crunch                    G    C       120        1    3
# Clusters                                 G    C       110        3    2
# Cocoa_Puffs                              G    C       110        1    1
# Corn_Chex                                R    C       110        2    0
# Corn_Flakes                              K    C       100        2    0
# Corn_Pops                                K    C       110        1    0
# Count_Chocula                            G    C       110        1    1
# Cracklin'_Oat_Bran                       K    C       110        3    3
# Cream_of_Wheat_(Quick)                   N    H       100        3    0
# Crispix                                  K    C       110        2    0
# Crispy_Wheat_&_Raisins                   G    C       100        2    1
# Double_Chex                              R    C       100        2    0
# Froot_Loops                              K    C       110        2    1
# Frosted_Flakes                           K    C       110        1    0
# Frosted_Mini-Wheats                      K    C       100        3    0
# Fruit_&_Fibre_Dates,_Walnuts,_and_Oats   P    C       120        3    2
# Fruitful_Bran                            K    C       120        3    0
# Fruity_Pebbles                           P    C       110        1    1
# ...                                     ..  ...       ...      ...  ...
# Multi-Grain_Cheerios                     G    C       100        2    1
# Nut&Honey_Crunch                         K    C       120        2    1
# Nutri-Grain_Almond-Raisin                K    C       140        3    2
# Nutri-grain_Wheat                        K    C        90        3    0
# Oatmeal_Raisin_Crisp                     G    C       130        3    2
# Post_Nat._Raisin_Bran                    P    C       120        3    1
# Product_19                               K    C       100        3    0
# Puffed_Rice                              Q    C        50        1    0
# Puffed_Wheat                             Q    C        50        2    0
# Quaker_Oat_Squares                       Q    C       100        4    1
# Quaker_Oatmeal                           Q    H       100        5    2
# Raisin_Bran                              K    C       120        3    1
# Raisin_Nut_Bran                          G    C       100        3    2
# Raisin_Squares                           K    C        90        2    0
# Rice_Chex                                R    C       110        1    0
# Rice_Krispies                            K    C       110        2    0
# Shredded_Wheat                           N    C        80        2    0
# Shredded_Wheat_'n'Bran                   N    C        90        3    0
# Shredded_Wheat_spoon_size                N    C        90        3    0
# Smacks                                   K    C       110        2    1
# Special_K                                K    C       110        6    0
# Strawberry_Fruit_Wheats                  N    C        90        2    0
# Total_Corn_Flakes                        G    C       110        2    1
# Total_Raisin_Bran                        G    C       140        3    1
# Total_Whole_Grain                        G    C       100        3    1
# Triples                                  G    C       110        2    1
# Trix                                     G    C       110        1    1
# Wheat_Chex                               R    C       100        3    1
# Wheaties                                 G    C       100        3    1
# Wheaties_Honey_Gold                      G    C       110        2    1
#
#                                         sodium  fiber  carbo  sugars  potass  \
# name
# 100%_Bran                                  130   10.0    5.0       6     280
# 100%_Natural_Bran                           15    2.0    8.0       8     135
# All-Bran                                   260    9.0    7.0       5     320
# All-Bran_with_Extra_Fiber                  140   14.0    8.0       0     330
# Almond_Delight                             200    1.0   14.0       8      -1
# Apple_Cinnamon_Cheerios                    180    1.5   10.5      10      70
# Apple_Jacks                                125    1.0   11.0      14      30
# Basic_4                                    210    2.0   18.0       8     100
# Bran_Chex                                  200    4.0   15.0       6     125
# Bran_Flakes                                210    5.0   13.0       5     190
# Cap'n'Crunch                               220    0.0   12.0      12      35
# Cheerios                                   290    2.0   17.0       1     105
# Cinnamon_Toast_Crunch                      210    0.0   13.0       9      45
# Clusters                                   140    2.0   13.0       7     105
# Cocoa_Puffs                                180    0.0   12.0      13      55
# Corn_Chex                                  280    0.0   22.0       3      25
# Corn_Flakes                                290    1.0   21.0       2      35
# Corn_Pops                                   90    1.0   13.0      12      20
# Count_Chocula                              180    0.0   12.0      13      65
# Cracklin'_Oat_Bran                         140    4.0   10.0       7     160
# Cream_of_Wheat_(Quick)                      80    1.0   21.0       0      -1
# Crispix                                    220    1.0   21.0       3      30
# Crispy_Wheat_&_Raisins                     140    2.0   11.0      10     120
# Double_Chex                                190    1.0   18.0       5      80
# Froot_Loops                                125    1.0   11.0      13      30
# Frosted_Flakes                             200    1.0   14.0      11      25
# Frosted_Mini-Wheats                          0    3.0   14.0       7     100
# Fruit_&_Fibre_Dates,_Walnuts,_and_Oats     160    5.0   12.0      10     200
# Fruitful_Bran                              240    5.0   14.0      12     190
# Fruity_Pebbles                             135    0.0   13.0      12      25
# ...                                        ...    ...    ...     ...     ...
# Multi-Grain_Cheerios                       220    2.0   15.0       6      90
# Nut&Honey_Crunch                           190    0.0   15.0       9      40
# Nutri-Grain_Almond-Raisin                  220    3.0   21.0       7     130
# Nutri-grain_Wheat                          170    3.0   18.0       2      90
# Oatmeal_Raisin_Crisp                       170    1.5   13.5      10     120
# Post_Nat._Raisin_Bran                      200    6.0   11.0      14     260
# Product_19                                 320    1.0   20.0       3      45
# Puffed_Rice                                  0    0.0   13.0       0      15
# Puffed_Wheat                                 0    1.0   10.0       0      50
# Quaker_Oat_Squares                         135    2.0   14.0       6     110
# Quaker_Oatmeal                               0    2.7   -1.0      -1     110
# Raisin_Bran                                210    5.0   14.0      12     240
# Raisin_Nut_Bran                            140    2.5   10.5       8     140
# Raisin_Squares                               0    2.0   15.0       6     110
# Rice_Chex                                  240    0.0   23.0       2      30
# Rice_Krispies                              290    0.0   22.0       3      35
# Shredded_Wheat                               0    3.0   16.0       0      95
# Shredded_Wheat_'n'Bran                       0    4.0   19.0       0     140
# Shredded_Wheat_spoon_size                    0    3.0   20.0       0     120
# Smacks                                      70    1.0    9.0      15      40
# Special_K                                  230    1.0   16.0       3      55
# Strawberry_Fruit_Wheats                     15    3.0   15.0       5      90
# Total_Corn_Flakes                          200    0.0   21.0       3      35
# Total_Raisin_Bran                          190    4.0   15.0      14     230
# Total_Whole_Grain                          200    3.0   16.0       3     110
# Triples                                    250    0.0   21.0       3      60
# Trix                                       140    0.0   13.0      12      25
# Wheat_Chex                                 230    3.0   17.0       3     115
# Wheaties                                   200    3.0   17.0       3     110
# Wheaties_Honey_Gold                        200    1.0   16.0       8      60
#
#                                         vitamins  shelf  weight  cups  \
# name
# 100%_Bran                                     25      3    1.00  0.33
# 100%_Natural_Bran                              0      3    1.00  1.00
# All-Bran                                      25      3    1.00  0.33
# All-Bran_with_Extra_Fiber                     25      3    1.00  0.50
# Almond_Delight                                25      3    1.00  0.75
# Apple_Cinnamon_Cheerios                       25      1    1.00  0.75
# Apple_Jacks                                   25      2    1.00  1.00
# Basic_4                                       25      3    1.33  0.75
# Bran_Chex                                     25      1    1.00  0.67
# Bran_Flakes                                   25      3    1.00  0.67
# Cap'n'Crunch                                  25      2    1.00  0.75
# Cheerios                                      25      1    1.00  1.25
# Cinnamon_Toast_Crunch                         25      2    1.00  0.75
# Clusters                                      25      3    1.00  0.50
# Cocoa_Puffs                                   25      2    1.00  1.00
# Corn_Chex                                     25      1    1.00  1.00
# Corn_Flakes                                   25      1    1.00  1.00
# Corn_Pops                                     25      2    1.00  1.00
# Count_Chocula                                 25      2    1.00  1.00
# Cracklin'_Oat_Bran                            25      3    1.00  0.50
# Cream_of_Wheat_(Quick)                         0      2    1.00  1.00
# Crispix                                       25      3    1.00  1.00
# Crispy_Wheat_&_Raisins                        25      3    1.00  0.75
# Double_Chex                                   25      3    1.00  0.75
# Froot_Loops                                   25      2    1.00  1.00
# Frosted_Flakes                                25      1    1.00  0.75
# Frosted_Mini-Wheats                           25      2    1.00  0.80
# Fruit_&_Fibre_Dates,_Walnuts,_and_Oats        25      3    1.25  0.67
# Fruitful_Bran                                 25      3    1.33  0.67
# Fruity_Pebbles                                25      2    1.00  0.75
# ...                                          ...    ...     ...   ...
# Multi-Grain_Cheerios                          25      1    1.00  1.00
# Nut&Honey_Crunch                              25      2    1.00  0.67
# Nutri-Grain_Almond-Raisin                     25      3    1.33  0.67
# Nutri-grain_Wheat                             25      3    1.00  1.00
# Oatmeal_Raisin_Crisp                          25      3    1.25  0.50
# Post_Nat._Raisin_Bran                         25      3    1.33  0.67
# Product_19                                   100      3    1.00  1.00
# Puffed_Rice                                    0      3    0.50  1.00
# Puffed_Wheat                                   0      3    0.50  1.00
# Quaker_Oat_Squares                            25      3    1.00  0.50
# Quaker_Oatmeal                                 0      1    1.00  0.67
# Raisin_Bran                                   25      2    1.33  0.75
# Raisin_Nut_Bran                               25      3    1.00  0.50
# Raisin_Squares                                25      3    1.00  0.50
# Rice_Chex                                     25      1    1.00  1.13
# Rice_Krispies                                 25      1    1.00  1.00
# Shredded_Wheat                                 0      1    0.83  1.00
# Shredded_Wheat_'n'Bran                         0      1    1.00  0.67
# Shredded_Wheat_spoon_size                      0      1    1.00  0.67
# Smacks                                        25      2    1.00  0.75
# Special_K                                     25      1    1.00  1.00
# Strawberry_Fruit_Wheats                       25      2    1.00  1.00
# Total_Corn_Flakes                            100      3    1.00  1.00
# Total_Raisin_Bran                            100      3    1.50  1.00
# Total_Whole_Grain                            100      3    1.00  1.00
# Triples                                       25      3    1.00  0.75
# Trix                                          25      2    1.00  1.00
# Wheat_Chex                                    25      1    1.00  0.67
# Wheaties                                      25      1    1.00  1.00
# Wheaties_Honey_Gold                           25      1    1.00  0.75
#
#                                            rating
# name
# 100%_Bran                               68.402973
# 100%_Natural_Bran                       33.983679
# All-Bran                                59.425505
# All-Bran_with_Extra_Fiber               93.704912
# Almond_Delight                          34.384843
# Apple_Cinnamon_Cheerios                 29.509541
# Apple_Jacks                             33.174094
# Basic_4                                 37.038562
# Bran_Chex                               49.120253
# Bran_Flakes                             53.313813
# Cap'n'Crunch                            18.042851
# Cheerios                                50.764999
# Cinnamon_Toast_Crunch                   19.823573
# Clusters                                40.400208
# Cocoa_Puffs                             22.736446
# Corn_Chex                               41.445019
# Corn_Flakes                             45.863324
# Corn_Pops                               35.782791
# Count_Chocula                           22.396513
# Cracklin'_Oat_Bran                      40.448772
# Cream_of_Wheat_(Quick)                  64.533816
# Crispix                                 46.895644
# Crispy_Wheat_&_Raisins                  36.176196
# Double_Chex                             44.330856
# Froot_Loops                             32.207582
# Frosted_Flakes                          31.435973
# Frosted_Mini-Wheats                     58.345141
# Fruit_&_Fibre_Dates,_Walnuts,_and_Oats  40.917047
# Fruitful_Bran                           41.015492
# Fruity_Pebbles                          28.025765
# ...                                           ...
# Multi-Grain_Cheerios                    40.105965
# Nut&Honey_Crunch                        29.924285
# Nutri-Grain_Almond-Raisin               40.692320
# Nutri-grain_Wheat                       59.642837
# Oatmeal_Raisin_Crisp                    30.450843
# Post_Nat._Raisin_Bran                   37.840594
# Product_19                              41.503540
# Puffed_Rice                             60.756112
# Puffed_Wheat                            63.005645
# Quaker_Oat_Squares                      49.511874
# Quaker_Oatmeal                          50.828392
# Raisin_Bran                             39.259197
# Raisin_Nut_Bran                         39.703400
# Raisin_Squares                          55.333142
# Rice_Chex                               41.998933
# Rice_Krispies                           40.560159
# Shredded_Wheat                          68.235885
# Shredded_Wheat_'n'Bran                  74.472949
# Shredded_Wheat_spoon_size               72.801787
# Smacks                                  31.230054
# Special_K                               53.131324
# Strawberry_Fruit_Wheats                 59.363993
# Total_Corn_Flakes                       38.839746
# Total_Raisin_Bran                       28.592785
# Total_Whole_Grain                       46.658844
# Triples                                 39.106174
# Trix                                    27.753301
# Wheat_Chex                              49.787445
# Wheaties                                51.592193
# Wheaties_Honey_Gold                     36.187559
#
# [77 rows x 15 columns]

# %% [markdown]
# A seguir iremos remover as linhas correspondentes aos cereais que possuem dados faltantes, representados pelo valor -1.
# Também iremos remover as colunas com dados categóricos 'mfr' e 'type', e os dados numéricos, 'shelf', 'weight' e 'cups'.

# %%
import numpy as np
new_df = df.replace(-1,np.nan)
new_df = new_df.dropna()
new_df = new_df.drop(['mfr','type','shelf','weight','cups'],axis=1)
new_df
# Out:
#                                         calories  protein  fat  sodium  fiber  \
# name
# 100%_Bran                                     70        4    1     130   10.0
# 100%_Natural_Bran                            120        3    5      15    2.0
# All-Bran                                      70        4    1     260    9.0
# All-Bran_with_Extra_Fiber                     50        4    0     140   14.0
# Apple_Cinnamon_Cheerios                      110        2    2     180    1.5
# Apple_Jacks                                  110        2    0     125    1.0
# Basic_4                                      130        3    2     210    2.0
# Bran_Chex                                     90        2    1     200    4.0
# Bran_Flakes                                   90        3    0     210    5.0
# Cap'n'Crunch                                 120        1    2     220    0.0
# Cheerios                                     110        6    2     290    2.0
# Cinnamon_Toast_Crunch                        120        1    3     210    0.0
# Clusters                                     110        3    2     140    2.0
# Cocoa_Puffs                                  110        1    1     180    0.0
# Corn_Chex                                    110        2    0     280    0.0
# Corn_Flakes                                  100        2    0     290    1.0
# Corn_Pops                                    110        1    0      90    1.0
# Count_Chocula                                110        1    1     180    0.0
# Cracklin'_Oat_Bran                           110        3    3     140    4.0
# Crispix                                      110        2    0     220    1.0
# Crispy_Wheat_&_Raisins                       100        2    1     140    2.0
# Double_Chex                                  100        2    0     190    1.0
# Froot_Loops                                  110        2    1     125    1.0
# Frosted_Flakes                               110        1    0     200    1.0
# Frosted_Mini-Wheats                          100        3    0       0    3.0
# Fruit_&_Fibre_Dates,_Walnuts,_and_Oats       120        3    2     160    5.0
# Fruitful_Bran                                120        3    0     240    5.0
# Fruity_Pebbles                               110        1    1     135    0.0
# Golden_Crisp                                 100        2    0      45    0.0
# Golden_Grahams                               110        1    1     280    0.0
# ...                                          ...      ...  ...     ...    ...
# Mueslix_Crispy_Blend                         160        3    2     150    3.0
# Multi-Grain_Cheerios                         100        2    1     220    2.0
# Nut&Honey_Crunch                             120        2    1     190    0.0
# Nutri-Grain_Almond-Raisin                    140        3    2     220    3.0
# Nutri-grain_Wheat                             90        3    0     170    3.0
# Oatmeal_Raisin_Crisp                         130        3    2     170    1.5
# Post_Nat._Raisin_Bran                        120        3    1     200    6.0
# Product_19                                   100        3    0     320    1.0
# Puffed_Rice                                   50        1    0       0    0.0
# Puffed_Wheat                                  50        2    0       0    1.0
# Quaker_Oat_Squares                           100        4    1     135    2.0
# Raisin_Bran                                  120        3    1     210    5.0
# Raisin_Nut_Bran                              100        3    2     140    2.5
# Raisin_Squares                                90        2    0       0    2.0
# Rice_Chex                                    110        1    0     240    0.0
# Rice_Krispies                                110        2    0     290    0.0
# Shredded_Wheat                                80        2    0       0    3.0
# Shredded_Wheat_'n'Bran                        90        3    0       0    4.0
# Shredded_Wheat_spoon_size                     90        3    0       0    3.0
# Smacks                                       110        2    1      70    1.0
# Special_K                                    110        6    0     230    1.0
# Strawberry_Fruit_Wheats                       90        2    0      15    3.0
# Total_Corn_Flakes                            110        2    1     200    0.0
# Total_Raisin_Bran                            140        3    1     190    4.0
# Total_Whole_Grain                            100        3    1     200    3.0
# Triples                                      110        2    1     250    0.0
# Trix                                         110        1    1     140    0.0
# Wheat_Chex                                   100        3    1     230    3.0
# Wheaties                                     100        3    1     200    3.0
# Wheaties_Honey_Gold                          110        2    1     200    1.0
#
#                                         carbo  sugars  potass  vitamins  \
# name
# 100%_Bran                                 5.0     6.0   280.0        25
# 100%_Natural_Bran                         8.0     8.0   135.0         0
# All-Bran                                  7.0     5.0   320.0        25
# All-Bran_with_Extra_Fiber                 8.0     0.0   330.0        25
# Apple_Cinnamon_Cheerios                  10.5    10.0    70.0        25
# Apple_Jacks                              11.0    14.0    30.0        25
# Basic_4                                  18.0     8.0   100.0        25
# Bran_Chex                                15.0     6.0   125.0        25
# Bran_Flakes                              13.0     5.0   190.0        25
# Cap'n'Crunch                             12.0    12.0    35.0        25
# Cheerios                                 17.0     1.0   105.0        25
# Cinnamon_Toast_Crunch                    13.0     9.0    45.0        25
# Clusters                                 13.0     7.0   105.0        25
# Cocoa_Puffs                              12.0    13.0    55.0        25
# Corn_Chex                                22.0     3.0    25.0        25
# Corn_Flakes                              21.0     2.0    35.0        25
# Corn_Pops                                13.0    12.0    20.0        25
# Count_Chocula                            12.0    13.0    65.0        25
# Cracklin'_Oat_Bran                       10.0     7.0   160.0        25
# Crispix                                  21.0     3.0    30.0        25
# Crispy_Wheat_&_Raisins                   11.0    10.0   120.0        25
# Double_Chex                              18.0     5.0    80.0        25
# Froot_Loops                              11.0    13.0    30.0        25
# Frosted_Flakes                           14.0    11.0    25.0        25
# Frosted_Mini-Wheats                      14.0     7.0   100.0        25
# Fruit_&_Fibre_Dates,_Walnuts,_and_Oats   12.0    10.0   200.0        25
# Fruitful_Bran                            14.0    12.0   190.0        25
# Fruity_Pebbles                           13.0    12.0    25.0        25
# Golden_Crisp                             11.0    15.0    40.0        25
# Golden_Grahams                           15.0     9.0    45.0        25
# ...                                       ...     ...     ...       ...
# Mueslix_Crispy_Blend                     17.0    13.0   160.0        25
# Multi-Grain_Cheerios                     15.0     6.0    90.0        25
# Nut&Honey_Crunch                         15.0     9.0    40.0        25
# Nutri-Grain_Almond-Raisin                21.0     7.0   130.0        25
# Nutri-grain_Wheat                        18.0     2.0    90.0        25
# Oatmeal_Raisin_Crisp                     13.5    10.0   120.0        25
# Post_Nat._Raisin_Bran                    11.0    14.0   260.0        25
# Product_19                               20.0     3.0    45.0       100
# Puffed_Rice                              13.0     0.0    15.0         0
# Puffed_Wheat                             10.0     0.0    50.0         0
# Quaker_Oat_Squares                       14.0     6.0   110.0        25
# Raisin_Bran                              14.0    12.0   240.0        25
# Raisin_Nut_Bran                          10.5     8.0   140.0        25
# Raisin_Squares                           15.0     6.0   110.0        25
# Rice_Chex                                23.0     2.0    30.0        25
# Rice_Krispies                            22.0     3.0    35.0        25
# Shredded_Wheat                           16.0     0.0    95.0         0
# Shredded_Wheat_'n'Bran                   19.0     0.0   140.0         0
# Shredded_Wheat_spoon_size                20.0     0.0   120.0         0
# Smacks                                    9.0    15.0    40.0        25
# Special_K                                16.0     3.0    55.0        25
# Strawberry_Fruit_Wheats                  15.0     5.0    90.0        25
# Total_Corn_Flakes                        21.0     3.0    35.0       100
# Total_Raisin_Bran                        15.0    14.0   230.0       100
# Total_Whole_Grain                        16.0     3.0   110.0       100
# Triples                                  21.0     3.0    60.0        25
# Trix                                     13.0    12.0    25.0        25
# Wheat_Chex                               17.0     3.0   115.0        25
# Wheaties                                 17.0     3.0   110.0        25
# Wheaties_Honey_Gold                      16.0     8.0    60.0        25
#
#                                            rating
# name
# 100%_Bran                               68.402973
# 100%_Natural_Bran                       33.983679
# All-Bran                                59.425505
# All-Bran_with_Extra_Fiber               93.704912
# Apple_Cinnamon_Cheerios                 29.509541
# Apple_Jacks                             33.174094
# Basic_4                                 37.038562
# Bran_Chex                               49.120253
# Bran_Flakes                             53.313813
# Cap'n'Crunch                            18.042851
# Cheerios                                50.764999
# Cinnamon_Toast_Crunch                   19.823573
# Clusters                                40.400208
# Cocoa_Puffs                             22.736446
# Corn_Chex                               41.445019
# Corn_Flakes                             45.863324
# Corn_Pops                               35.782791
# Count_Chocula                           22.396513
# Cracklin'_Oat_Bran                      40.448772
# Crispix                                 46.895644
# Crispy_Wheat_&_Raisins                  36.176196
# Double_Chex                             44.330856
# Froot_Loops                             32.207582
# Frosted_Flakes                          31.435973
# Frosted_Mini-Wheats                     58.345141
# Fruit_&_Fibre_Dates,_Walnuts,_and_Oats  40.917047
# Fruitful_Bran                           41.015492
# Fruity_Pebbles                          28.025765
# Golden_Crisp                            35.252444
# Golden_Grahams                          23.804043
# ...                                           ...
# Mueslix_Crispy_Blend                    30.313351
# Multi-Grain_Cheerios                    40.105965
# Nut&Honey_Crunch                        29.924285
# Nutri-Grain_Almond-Raisin               40.692320
# Nutri-grain_Wheat                       59.642837
# Oatmeal_Raisin_Crisp                    30.450843
# Post_Nat._Raisin_Bran                   37.840594
# Product_19                              41.503540
# Puffed_Rice                             60.756112
# Puffed_Wheat                            63.005645
# Quaker_Oat_Squares                      49.511874
# Raisin_Bran                             39.259197
# Raisin_Nut_Bran                         39.703400
# Raisin_Squares                          55.333142
# Rice_Chex                               41.998933
# Rice_Krispies                           40.560159
# Shredded_Wheat                          68.235885
# Shredded_Wheat_'n'Bran                  74.472949
# Shredded_Wheat_spoon_size               72.801787
# Smacks                                  31.230054
# Special_K                               53.131324
# Strawberry_Fruit_Wheats                 59.363993
# Total_Corn_Flakes                       38.839746
# Total_Raisin_Bran                       28.592785
# Total_Whole_Grain                       46.658844
# Triples                                 39.106174
# Trix                                    27.753301
# Wheat_Chex                              49.787445
# Wheaties                                51.592193
# Wheaties_Honey_Gold                     36.187559
#
# [74 rows x 10 columns]

# %% [markdown]
# Finalmente, iremos converter os dados nutricionais numéricos de ```new_df``` para uma matriz ```dados``` e as avaliações (ratings) para um vetor $y$. Os nomes dos cereais serão salvos em uma lista ```cereral_names``` e os nomes das colunas em uma lista ```col_names```.

# %%
cereral_names = list(new_df.index)
print('Cereais:',cereral_names)
col_names = list(new_df.columns)
print('Colunas:',col_names)

dados = new_df.drop('rating', axis=1).values
print('As dimensões de dados são:',dados.shape)
y = new_df['rating'].values
print('As dimensões de y são:',y.shape)
# Out:
# Cereais: ['100%_Bran', '100%_Natural_Bran', 'All-Bran', 'All-Bran_with_Extra_Fiber', 'Apple_Cinnamon_Cheerios', 'Apple_Jacks', 'Basic_4', 'Bran_Chex', 'Bran_Flakes', "Cap'n'Crunch", 'Cheerios', 'Cinnamon_Toast_Crunch', 'Clusters', 'Cocoa_Puffs', 'Corn_Chex', 'Corn_Flakes', 'Corn_Pops', 'Count_Chocula', "Cracklin'_Oat_Bran", 'Crispix', 'Crispy_Wheat_&_Raisins', 'Double_Chex', 'Froot_Loops', 'Frosted_Flakes', 'Frosted_Mini-Wheats', 'Fruit_&_Fibre_Dates,_Walnuts,_and_Oats', 'Fruitful_Bran', 'Fruity_Pebbles', 'Golden_Crisp', 'Golden_Grahams', 'Grape_Nuts_Flakes', 'Grape-Nuts', 'Great_Grains_Pecan', 'Honey_Graham_Ohs', 'Honey_Nut_Cheerios', 'Honey-comb', 'Just_Right_Crunchy__Nuggets', 'Just_Right_Fruit_&_Nut', 'Kix', 'Life', 'Lucky_Charms', 'Maypo', 'Muesli_Raisins,_Dates,_&_Almonds', 'Muesli_Raisins,_Peaches,_&_Pecans', 'Mueslix_Crispy_Blend', 'Multi-Grain_Cheerios', 'Nut&Honey_Crunch', 'Nutri-Grain_Almond-Raisin', 'Nutri-grain_Wheat', 'Oatmeal_Raisin_Crisp', 'Post_Nat._Raisin_Bran', 'Product_19', 'Puffed_Rice', 'Puffed_Wheat', 'Quaker_Oat_Squares', 'Raisin_Bran', 'Raisin_Nut_Bran', 'Raisin_Squares', 'Rice_Chex', 'Rice_Krispies', 'Shredded_Wheat', "Shredded_Wheat_'n'Bran", 'Shredded_Wheat_spoon_size', 'Smacks', 'Special_K', 'Strawberry_Fruit_Wheats', 'Total_Corn_Flakes', 'Total_Raisin_Bran', 'Total_Whole_Grain', 'Triples', 'Trix', 'Wheat_Chex', 'Wheaties', 'Wheaties_Honey_Gold']
# Colunas: ['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins', 'rating']
# As dimensões de dados são: (74, 9)
# As dimensões de y são: (74,)

# %% [markdown]
# ## Estimando os parâmetros da regressão linear simples
#
# Qual será a relação entre a avaliação $y$ e o número de calorias $x$ de um cereal? Para responder esta pergunta, considere uma regressão linear simples
# $$
# y = \beta_0 + \beta_1 x.
# $$
# Para encontrar os coeficientes $\beta_0$ e $\beta_1$ utilizando o método dos mínimos quadrados, basta resolver o sistema
# $$
# \begin{bmatrix}
# n & \sum_i x^{(i)} \\
# \sum_i x^{(i)} & \sum_i (x^{(i)})^2
# \end{bmatrix}
# \begin{bmatrix}
# \beta_0 \\ \beta_1
# \end{bmatrix}
# =
# \begin{bmatrix}
# \sum_i y^{(i)} \\ \sum_i x^{(i)} y^{(i)}
# \end{bmatrix}
# $$
#
# Portanto, para encontrar $\beta_0$ e $\beta_1$, você precisa
# 1. Calcular a matriz
# $$
# A = \begin{bmatrix}
# n & \sum_i x^{(i)} \\
# \sum_i x^{(i)} & \sum_i (x^{(i)})^2
# \end{bmatrix}
# $$
# e o vetor
# $$
# c = \begin{bmatrix}
# \sum_i y^{(i)} \\ \sum_i x^{(i)} y^{(i)}
# \end{bmatrix}
# $$
# 2. Resolver $A \beta = c$, onde $\beta$ é o vetor de coeficientes.

# %% [markdown]
# **Exercício 1 - Regressão simples:** Encontre os coeficientes $\beta_0$ e $\beta_1$ quando a variável independente é ```calories```. Dica: A variavel X abaixo já armazena os valores deste atributo.

# %%
X = new_df['calories'].values

# insira seu código aqui
X_1 =  np.stack((np.ones(X.shape[0]), X))
A = X_1 @ X_1.T
c = X_1 @ y
B_simples = np.linalg.inv(A) @ c
B_simples
# Out:
# array([ 94.88442777,  -0.49064841])

# %% [markdown]
# **Exercício 2 - Regressão múltipla:** Considerando a nova tabela de dados X abaixo com os atributos 'calories', 'protein', 'fat', 'sugars' e 'vitamins' selecionados, estime os parâmetros da regressão múltipla para obter a variavel resposta ```rating```

# %%
X = new_df.loc[:,['calories', 'protein', 'fat', 'sugars', 'vitamins']].values

# insira seu código aqui
X_1 = np.insert(X,0,1, axis=1).T
A = X_1 @ X_1.T
c = X_1 @ y
B_multi = np.linalg.inv(A) @ c
B_multi
# Out:
# array([ 69.6495031 ,  -0.2618972 ,   5.55855063,  -2.8585006 ,
#         -1.14383072,  -0.07675886])

# %% [markdown]
# **Exercício 3:** Nossos modelos de regressão linear são bons preditores da nota de avaliação do cereal? Qual o melhor modelo? Calcule os coeficientes de determinação e faça uma análise dos valores obtidos para responder a estas perguntas.

# %%
# insira seu código aqui
def calc_r2(fit):
    med = y.mean()
    return np.sum((fit-med)**2) / np.sum((y-med)**2)

y_simples = B_simples[0] + (B_simples[1] * new_df['calories'].values)
R2_simples = calc_r2(y_simples)

y_multi = B_multi[0] + np.sum(new_df.loc[:,['calories', 'protein', 'fat', 'sugars', 'vitamins']].values * B_multi[1:], axis=1)
R2_multi = calc_r2(y_multi)
print(f"R2 Fit Simples: {R2_simples*100:.2f}%\nR2 Fit Múltiplo: {R2_multi*100:.2f}%\nDiferença: {R2_simples/R2_multi:.2f}")
# Out:
# R2 Fit Simples: 48.13%
# R2 Fit Múltiplo: 83.38%
# Diferença: 0.58

# %% [markdown]
# Os modelos não são muito acurados, porém mesmo assim há uma grande melhora do modelo simples para o modelo multivariável. Talvez o modelo simples seria melhor se baseado em proteínas ao invés de calorias.
